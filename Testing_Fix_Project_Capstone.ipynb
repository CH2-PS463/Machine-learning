# %%
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
test_set = tf.keras.utils.image_dataset_from_directory(
    '/content/drive/MyDrive/Project/Vegetable_Images/test',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(64, 64),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 2630 files belonging to 15 classes.

# %%
cnn = tf.keras.models.load_model('/content/trained_model.h5')

# %%
import cv2
image_path = '/content/drive/MyDrive/Project/Vegetable_Images/test/Capsicum/1004.jpg'

img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 0s 271ms/step

# %%
print(predictions)
# Out:
# [[3.4152817e-15 5.9759440e-16 1.3135870e-09 1.5359801e-15 2.9684468e-16
#   3.2000787e-19 1.0000000e+00 1.7981666e-18 1.0270840e-19 1.3194934e-16
#   4.9008442e-14 3.8005376e-18 1.5088459e-14 1.4011617e-18 7.9014482e-17]]

# %%
test_set.class_names
# Out:
# ['Bean',
#  'Bitter_Gourd',
#  'Bottle_Gourd',
#  'Brinjal',
#  'Broccoli',
#  'Cabbage',
#  'Capsicum',
#  'Carrot',
#  'Cauliflower',
#  'Cucumber',
#  'Papaya',
#  'Potato',
#  'Pumpkin',
#  'Radish',
#  'Tomato']

# %%
result_index = np.argmax(predictions)
print(result_index)
# Out:
# 6

# %%
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
print("Ini Adalah = {}".format(test_set.class_names[result_index]))
# Out:
# Ini Adalah = Capsicum
